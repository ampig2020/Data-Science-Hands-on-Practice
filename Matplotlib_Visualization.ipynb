# %% [markdown]
# <a href="https://colab.research.google.com/github/ampig2020/Data-Science-Hands-on-Practice/blob/main/Matplotlib_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py'>

# %%
plt.title('Sin from 0 to 2*pi')
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
plt.title('Sin from 0 to 2*pi')
x = np.linspace(0, 2*np.pi, 20)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
plt.title('Sin from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x,y)
plt.show()

# %%
y2 = np.cos(x)
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, y)
plt.plot(x, y2)
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, y, label='sine')
plt.plot(x, y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Minus Sin and Minus Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend(loc='lower center')
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('Sin and Cos from 0 to 2*pi')
plt.ylabel('Sin')
plt.plot(x, y)

plt.subplot(2, 1, 2)
plt.ylabel('Cos')
plt.plot(x, y2)
plt.show()

# %%
plt.title('Minus Sin and Minus Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, 'ro', label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Minus Sin and Minus Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, 'ro', label='sine')
plt.plot(x, -y2, marker='^', color='g', label='cosine', linewidth=0)
plt.legend()
plt.show()

# %%
plt.title('Sin and Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend(loc='lower center')
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.title('Sin and Cos from 0 to 2*pi')
plt.ylabel('Sin')
plt.plot(x, y)

plt.subplot(2, 1, 2)
plt.ylabel('Cos')
plt.plot(x, y2)
plt.show()

# %%
plt.title('Minus Sin and Minus Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, 'ro', label='sine')
plt.plot(x, -y2, label='cosine')
plt.legend()
plt.show()

# %%
plt.title('Minus Sin and Minus Cos from 0 to 2*pi')
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x, -y, 'ro', label='sine')
plt.plot(x, -y2, marker='^', color='g', label='cosine', linewidth=0)
plt.legend()
plt.show()
